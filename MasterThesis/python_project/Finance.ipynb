# %%
import pandas as pd

# %%
df = pd.DataFrame([10,20,30,40], columns=['numbers'], index=['a','b','c','d'])

# %%
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
#BASIC attributes
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['numbers'], dtype='object')

# %%
df.loc['c']
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
df.loc['a':'d']
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
df.iloc[2]
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
df.sum()
# Out:
# numbers    100
# dtype: int64

# %%
df.apply(lambda x: x**2)
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df**2
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
df['floats']=[2.11,3.22,5.04,6.70]

# %%
df
# Out:
#    numbers  floats
# a       10    2.11
# b       20    3.22
# c       30    5.04
# d       40    6.70

# %%
df['names']=pd.DataFrame(['one','two','three','four'],index=['a','b','c','d'])

# %%
df
# Out:
#    numbers  floats  names
# a       10    2.11    one
# b       20    3.22    two
# c       30    5.04  three
# d       40    6.70   four

# %%
df.loc['a':'c']
# Out:
#    numbers  floats  names
# a       10    2.11    one
# b       20    3.22    two
# c       30    5.04  three

# %%
df.loc['a':'c','names']
# Out:
# a      one
# b      two
# c    three
# Name: names, dtype: object

# %%
df.loc['a':'c',['names','numbers']]
# Out:
#    names  numbers
# a    one       10
# b    two       20
# c  three       30

# %%
pd.concat([df, pd.Series({'numbers':50,'floats':3.33,'names':'six'})], ignore_index=True)
# Out:
#    numbers  floats  names     0
# 0     10.0    2.11    one   NaN
# 1     20.0    3.22    two   NaN
# 2     30.0    5.04  three   NaN
# 3     40.0    6.70   four   NaN
# 4      NaN     NaN    NaN    50
# 5      NaN     NaN    NaN  3.33
# 6      NaN     NaN    NaN   six

# %%
df
# Out:
#    numbers  floats  names
# a       10    2.11    one
# b       20    3.22    two
# c       30    5.04  three
# d       40    6.70   four

# %%
df[['numbers','floats']].mean()
# Out:
# numbers    25.0000
# floats      4.2675
# dtype: float64

# %%
df[['numbers','floats']].std()
# Out:
# numbers    12.909944
# floats      2.022035
# dtype: float64

# %%
import numpy as np

# %%
np.random.seed(100)

# %%
np.random.standard_normal(size=10)
# Out:
# array([-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604,  0.98132079,
#         0.51421884,  0.22117967, -1.07004333, -0.18949583,  0.25500144])

# %%
a=np.random.standard_normal((4,2))

# %%
df = pd.DataFrame(a)

# %%
df.head()
# Out:
#           0         1
# 0 -0.438136 -1.118318
# 1  1.618982  1.541605
# 2 -0.251879 -0.842436
# 3  0.184519  0.937082

# %%
df.columns = ['no1','no2']

# %%
df
# Out:
#         no1       no2
# 0 -0.438136 -1.118318
# 1  1.618982  1.541605
# 2 -0.251879 -0.842436
# 3  0.184519  0.937082

# %%
df.mean(axis=0)
# Out:
# no1    0.278371
# no2    0.129483
# dtype: float64

# %%
dates=pd.date_range('2019-1-1',periods=4,freq='ME')

# %%
df.index=dates

# %%
df
# Out:
#                  no1       no2
# 2019-01-31 -0.438136 -1.118318
# 2019-02-28  1.618982  1.541605
# 2019-03-31 -0.251879 -0.842436
# 2019-04-30  0.184519  0.937082

# %%
# %matplotlib inline

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
np.linspace(2,10,5)
# Out:
# array([ 2.,  4.,  6.,  8., 10.])
